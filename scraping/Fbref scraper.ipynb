# %% [markdown]
# # Scraping FBREF

# %% [markdown]
# ### Import Required Libraries

# %%
from selenium import webdriver 
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import ElementClickInterceptedException
import pandas as pd

# %% [markdown]
# ## Fetching teams from top 5 leagues to include in our model

# %% [markdown]
# ### seting leagues websites

# %%
# create variables for the URLs of the leagues
PLurl = "https://fbref.com/fr/comps/9/Statistiques-Premier-League"
LaligaUrl = "https://fbref.com/fr/comps/12/Statistiques-La-Liga"
BundesligaUrl = "https://fbref.com/fr/comps/20/Statistiques-Bundesliga" 
SerieAUrl = "https://fbref.com/fr/comps/11/Statistiques-Serie-A"
Ligue1Url = "https://fbref.com/fr/comps/13/Statistiques-Ligue-1"

# %%
# create path variable
path = "C:\\Users\\azedd\\Downloads\\chromedriver-win64\\chromedriver.exe"

# Create teams dataframe
teamsdf = pd.DataFrame(columns=['Team','league'])

# Develop a fetch function
def teams_fetch(url):
    
    # set up the webdriver
    driver = webdriver.Chrome(service=webdriver.ChromeService(executable_path=path))
    driver.get(url)
    teams = driver.find_elements(By.XPATH, f"//td[@data-stat = 'team']")

    # Extracting the league name from the URL
    league = url.split('-')
    league.pop(0)
    league = " ".join([str(x) for x in league])
    
    # Adding team names and league to the Dataframe
    for team in teams :

        if team.text not in teamsdf['Team'].values:

            teamsdf.loc[len(teamsdf)] = [team.text, league]


    # close the driver
    driver.quit()
    return teamsdf

# %%
teams_fetch(PLurl)
teams_fetch(LaligaUrl)
teams_fetch(BundesligaUrl)
teams_fetch(SerieAUrl)
teams_fetch(Ligue1Url)
# Out:
#                Team          league
# 0         Liverpool  Premier League
# 1           Arsenal  Premier League
# 2   Manchester City  Premier League
# 3           Chelsea  Premier League
# 4     Newcastle Utd  Premier League
# ..              ...             ...
# 92           Angers         Ligue 1
# 93         Le Havre         Ligue 1
# 94            Reims         Ligue 1
# 95    Saint-Étienne         Ligue 1
# 96      Montpellier         Ligue 1
#
# [97 rows x 2 columns]

# %% [markdown]
# ## Now let's fetch players data

# %% [markdown]
# ### Create players dataframe

# %%
playersDF = pd.DataFrame(columns=[
    'Player',
    'Nation',
    'Position',
    'Age',
    'Matches Played',
    'Starts',
    'Minutes',
    '90s Played',
    'Goals',
    'Assists',
    'Goals + Assists',
    'Non-Penalty Goals',
    'Penalty Goals Made',
    'Penalty Attempts',
    'Yellow Cards',
    'Red Cards',
    'xG',
    'npxG',
    'xAG',
    'npxG + xAG',
    'Progressive Carries',
    'Progressive Passes',
    'Progressive Receives',
    'Goals Per 90',
    'Assists Per 90',
    'Goals + Assists Per 90',
    'Non-Penalty Goals Per 90',
    'Non-Penalty Goals + Assists Per 90',
    'xG Per 90',
    'xAG Per 90',
    'xG + xAG Per 90',
    'npxG Per 90',
    'npxG + xAG Per 90'
])

# %%
fetchedteams = []
notfetched = []

# %% [markdown]
# ### Fetching function

# %%
# create function that scrap all players data from a team name
def players_fetch(team_name):

    # set up the webdriver
    Url = f"https://fbref.com/fr"
    driver = webdriver.Chrome(service=webdriver.ChromeService(executable_path=path))
    driver.get(Url)

    # create an automation to search teams
    try : 
        team_search = driver.find_element(By.XPATH, "//input[@tabindex = '1'][@type = 'search']")
        team_search.send_keys(team_name + Keys.ENTER)
        team_page = driver.find_element(By.LINK_TEXT, F"{team_name}")
        team_page.click()


    except NoSuchElementException or ElementClickInterceptedException as err:
        drive = driver.find_element(By.XPATH, "//*[@id='sh_squads-tab']")
        drive.click()
        team_page = driver.find_element(By.XPATH, "//*[@id='sh_squads']/div[1]/div[1]/strong")
        team_page.click()

        


    
    position = ['AT', 'DF', 'MT,DF','MT,AT', 'MT', 'GB']
    for i in range(37):
        
        try:
            data = driver.find_element(By.XPATH,f"//tr [@data-row = '{i}']")
            
        except NoSuchElementException as err :
            saison = driver.find_element(By.XPATH,"//div [@class = 'button2 prev']")
            saison.click()
            data = driver.find_element(By.XPATH,f"//tr [@data-row = '{i}']")
            

        
        data = data.text.split(' ')
        data.pop(-1)
        if len(data) < 33:
            continue

        #searching for position index and handling name problems
        if data[3] in position:
            data.pop(1)
            playersDF.loc[len(playersDF)] = data
    
        elif data[4] in position:
            name = data.pop(0) + " " + data.pop(0)
            data.insert(0, name)
            data.pop(1)
            playersDF.loc[len(playersDF)] = data
            
        elif data[5] in position:
            name = data.pop(0) + " " + data.pop(0) + " " + data.pop(0)
            data.insert(0, name)
            data.pop(1)
            playersDF.loc[len(playersDF)] = data
        
        
    driver.quit()
    fetchedteams.append(team_name)
    return f"{team_name} players data fetched successfully!"

# %% [markdown]
# ### Testing

# %%
# Example usage to fetch players from Liverpool
players_fetch("Liverpool")
# Out:
# 'Liverpool players data fetched successfully!'

# %%
# see what the players dataframe looks like
print(playersDF.info())
playersDF
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24 entries, 0 to 23
# Data columns (total 33 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Player                              24 non-null     object
#  1   Nation                              24 non-null     object
#  2   Position                            24 non-null     object
#  3   Age                                 24 non-null     object
#  4   Matches Played                      24 non-null     object
#  5   Starts                              24 non-null     object
#  6   Minutes                             24 non-null     object
#  7   90s Played                          24 non-null     object
#  8   Goals                               24 non-null     object
#  9   Assists                             24 non-null     object
#  10  Goals + Assists                     24 non-null     object
#  11  Non-Penalty Goals                   24 non-null     object
#  12  Penalty Goals Made                  24 non-null     object
#  13  Penalty Attempts                    24 non-null     object
#  14  Yellow Cards                        24 non-null     object
#  15  Red Cards                           24 non-null     object
#  16  xG                                  24 non-null     object
#  17  npxG                                24 non-null     object
#  18  xAG                                 24 non-null     object
#  19  npxG + xAG                          24 non-null     object
#  20  Progressive Carries                 24 non-null     object
#  21  Progressive Passes                  24 non-null     object
#  22  Progressive Receives                24 non-null     object
#  23  Goals Per 90                        24 non-null     object
#  24  Assists Per 90                      24 non-null     object
#  25  Goals + Assists Per 90              24 non-null     object
#  26  Non-Penalty Goals Per 90            24 non-null     object
#  27  Non-Penalty Goals + Assists Per 90  24 non-null     object
#  28  xG Per 90                           24 non-null     object
#  29  xAG Per 90                          24 non-null     object
#  30  xG + xAG Per 90                     24 non-null     object
#  31  npxG Per 90                         24 non-null     object
#  32  npxG + xAG Per 90                   24 non-null     object
# dtypes: object(33)
# memory usage: 6.4+ KB
# None
#                     Player Nation Position Age Matches Played Starts Minutes  \
# 0            Mohamed Salah    EGY       AT  32             38     38   3,371
# 1          Virgil van Dijk    NED       DF  33             37     37   3,330
# 2         Ryan Gravenberch    NED       MT  22             37     37   3,160
# 3      Alexis Mac Allister    ARG       MT  25             35     30   2,599
# 4          Ibrahima Konaté    FRA       DF  25             31     30   2,560
# 5       Dominik Szoboszlai    HUN       MT  23             36     29   2,491
# 6         Andrew Robertson    SCO       DF  30             33     29   2,482
# 7                  Alisson    BRA       GB  31             28     28   2,508
# 8                Luis Díaz    COL       AT  27             36     28   2,399
# 9   Trent Alexander-Arnold    ENG       DF  25             33     28   2,365
# 10              Cody Gakpo    NED       AT  25             35     23   1,935
# 11            Curtis Jones    ENG    MT,DF  23             33     19   1,712
# 12              Diogo Jota    POR       AT  27             26     14   1,196
# 13       Caoimhín Kelleher    IRL       GB  25             10     10     900
# 14         Kostas Tsimikas    GRE       DF  28             18      9     837
# 15            Darwin Núñez    URU       AT  25             30      8   1,133
# 16           Conor Bradley    NIR       DF  21             19      7     754
# 17               Joe Gomez    ENG       DF  27              9      6     519
# 18          Jarell Quansah    ENG       DF  21             13      4     495
# 19          Harvey Elliott    ENG       MT  21             18      2     371
# 20             Wataru Endo    JPN    MT,DF  31             20      1     273
# 21         Federico Chiesa    ITA       AT  26              6      1     108
# 22         Vitezslav Jaros    CZE       GB  23              1      0      12
# 23            Jayden Danns    ENG       MT  18              1      0      11
#
#    90s Played Goals Assists  ... Goals Per 90 Assists Per 90  \
# 0        37.5    29      18  ...         0.77           0.48
# 1        37.0     3       1  ...         0.08           0.03
# 2        35.1     0       4  ...         0.00           0.11
# 3        28.9     5       5  ...         0.17           0.17
# 4        28.4     1       2  ...         0.04           0.07
# 5        27.7     6       6  ...         0.22           0.22
# 6        27.6     0       1  ...         0.00           0.04
# 7        27.9     0       0  ...         0.00           0.00
# 8        26.7    13       5  ...         0.49           0.19
# 9        26.3     3       6  ...         0.11           0.23
# 10       21.5    10       4  ...         0.47           0.19
# 11       19.0     3       3  ...         0.16           0.16
# 12       13.3     6       3  ...         0.45           0.23
# 13       10.0     0       0  ...         0.00           0.00
# 14        9.3     0       1  ...         0.00           0.11
# 15       12.6     5       2  ...         0.40           0.16
# 16        8.4     0       2  ...         0.00           0.24
# 17        5.8     0       0  ...         0.00           0.00
# 18        5.5     0       0  ...         0.00           0.00
# 19        4.1     1       2  ...         0.24           0.49
# 20        3.0     0       0  ...         0.00           0.00
# 21        1.2     0       0  ...         0.00           0.00
# 22        0.1     0       0  ...         0.00           0.00
# 23        0.1     0       0  ...         0.00           0.00
#
#    Goals + Assists Per 90 Non-Penalty Goals Per 90  \
# 0                    1.25                     0.53
# 1                    0.11                     0.08
# 2                    0.11                     0.00
# 3                    0.35                     0.17
# 4                    0.11                     0.04
# 5                    0.43                     0.22
# 6                    0.04                     0.00
# 7                    0.00                     0.00
# 8                    0.68                     0.49
# 9                    0.34                     0.11
# 10                   0.65                     0.47
# 11                   0.32                     0.16
# 12                   0.68                     0.45
# 13                   0.00                     0.00
# 14                   0.11                     0.00
# 15                   0.56                     0.40
# 16                   0.24                     0.00
# 17                   0.00                     0.00
# 18                   0.00                     0.00
# 19                   0.73                     0.24
# 20                   0.00                     0.00
# 21                   0.00                     0.00
# 22                   0.00                     0.00
# 23                   0.00                     0.00
#
#    Non-Penalty Goals + Assists Per 90 xG Per 90 xAG Per 90 xG + xAG Per 90  \
# 0                                1.01      0.67       0.38            1.05
# 1                                0.11      0.06       0.02            0.08
# 2                                0.11      0.03       0.09            0.12
# 3                                0.35      0.10       0.16            0.26
# 4                                0.11      0.06       0.03            0.10
# 5                                0.43      0.27       0.27            0.53
# 6                                0.04      0.04       0.17            0.21
# 7                                0.00      0.00       0.02            0.02
# 8                                0.68      0.45       0.19            0.64
# 9                                0.34      0.07       0.28            0.35
# 10                               0.65      0.33       0.20            0.53
# 11                               0.32      0.23       0.06            0.29
# 12                               0.68      0.60       0.14            0.74
# 13                               0.00      0.00       0.00            0.00
# 14                               0.11      0.04       0.23            0.27
# 15                               0.56      0.46       0.10            0.57
# 16                               0.24      0.08       0.17            0.25
# 17                               0.00      0.06       0.02            0.08
# 18                               0.00      0.02       0.02            0.04
# 19                               0.73      0.43       0.26            0.69
# 20                               0.00      0.00       0.02            0.02
# 21                               0.00      0.28       0.15            0.43
# 22                               0.00      0.00       0.00            0.00
# 23                               0.00      0.00       0.00            0.00
#
#    npxG Per 90 npxG + xAG Per 90
# 0         0.49              0.87
# 1         0.06              0.08
# 2         0.03              0.12
# 3         0.10              0.26
# 4         0.06              0.10
# 5         0.27              0.53
# 6         0.04              0.21
# 7         0.00              0.02
# 8         0.45              0.64
# 9         0.07              0.35
# 10        0.33              0.53
# 11        0.23              0.29
# 12        0.60              0.74
# 13        0.00              0.00
# 14        0.04              0.27
# 15        0.46              0.57
# 16        0.08              0.25
# 17        0.06              0.08
# 18        0.02              0.04
# 19        0.43              0.69
# 20        0.00              0.02
# 21        0.28              0.43
# 22        0.00              0.00
# 23        0.00              0.00
#
# [24 rows x 33 columns]

# %% [markdown]
# ### Now, let's fetch

# %%
for team in teamsdf['Team'].values:
    if team in fetchedteams:
        continue
    try:
        print(players_fetch(team))
        fetchedteams.append(team)
    except Exception as e:
        print(f"Error fetching data for {team}: {e}")
        if team not in notfetched:
            notfetched.append(team)
        continue

# %% [markdown]
# ### See the teams for which we lack player data

# %%
# Print Unfetchd Teams
print(notfetched)
# Out:
# ['Newcastle Utd', "Nott'ham", 'Manchester Utd', 'Wolves', 'St. Pauli', ' ']

# %% [markdown]
# ### Fixing unfetched teams

# %%
teamsdf.loc[4, 'Team'] = "Newcastle United"  
teamsdf.loc[14, 'Team'] = "Manchester United"  
teamsdf.loc[6, 'Team'] = "Nottingham Forest"
teamsdf.loc[54, 'Team'] = "St pauli"
teamsdf.loc[15, 'Team'] = "Wolverhampton Wanderers"
teamsdf = teamsdf.drop(20)

# %%
#Checking for any unfetched teams
notfetched == []
# Out:
# True

# %% [markdown]
# ### Save the players data to a CSV file

# %%
playersDF.to_csv("players_data.csv")
teamsdf.to_csv("teams_data.csv")
